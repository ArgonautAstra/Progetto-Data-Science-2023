# %%
from sklearn.datasets import load_digits
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt

 
data = load_digits().data
pca = PCA(2)  #per visualizzare il plot del clustering 2D
 
df = pca.fit_transform(data)
 
df.shape
# Out:
# (1797, 2)

# %%
from sklearn.cluster import KMeans
 
kmeans = KMeans(n_clusters= 10) #sappiamo che sono 10 cluster perchè le label vanno da 0 a 9
 
label = kmeans.fit_predict(df) #effettua la clusterizzazione
 
print(label)
# Out:
# [6 7 1 ... 1 0 8]
# c:\Users\Raffaele\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
filtered_zero = df[label==0]
print(filtered_zero.shape)

#plot del cluster con label 0
plt.scatter(filtered_zero[:,0] , filtered_zero[:,1])
plt.show()
# Out:
# (184, 2)
